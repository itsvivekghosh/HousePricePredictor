# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
# Out:
# F:\Anaconda\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df=pd.read_csv("House Datasets/train.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
plt.figure(figsize=(20, 8))
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
for feature in df.columns:
    
    if(np.round(df[feature].isnull().mean()*100, 2) > 0.0):
        print("{} has {}% of null values i.e {} out of {}".format(
            feature,
            np.round(df[feature].isnull().mean()*100, 2),
            (df[feature].isnull().sum()),
            len(df)
        ))
# Out:
# LotFrontage has 17.74% of null values i.e 259 out of 1460
# Alley has 93.77% of null values i.e 1369 out of 1460
# MasVnrType has 0.55% of null values i.e 8 out of 1460
# MasVnrArea has 0.55% of null values i.e 8 out of 1460
# BsmtQual has 2.53% of null values i.e 37 out of 1460
# BsmtCond has 2.53% of null values i.e 37 out of 1460
# BsmtExposure has 2.6% of null values i.e 38 out of 1460
# BsmtFinType1 has 2.53% of null values i.e 37 out of 1460
# BsmtFinType2 has 2.6% of null values i.e 38 out of 1460
# Electrical has 0.07% of null values i.e 1 out of 1460
# FireplaceQu has 47.26% of null values i.e 690 out of 1460
# GarageType has 5.55% of null values i.e 81 out of 1460
# GarageYrBlt has 5.55% of null values i.e 81 out of 1460
# GarageFinish has 5.55% of null values i.e 81 out of 1460
# GarageQual has 5.55% of null values i.e 81 out of 1460
# GarageCond has 5.55% of null values i.e 81 out of 1460
# PoolQC has 99.52% of null values i.e 1453 out of 1460
# ...

# %%
df['LotFrontage']=df['LotFrontage'].fillna(df['LotFrontage'].mean())

# %%
df.drop(["Alley", "Id"], axis=1, inplace=True)

# %%
df["MasVnrArea"]=df.MasVnrArea.fillna(df.MasVnrArea.mean())
df["MasVnrType"]=df.MasVnrType.fillna(df["MasVnrType"].mode()[0])

# %%
bsmt_features=[x for x in df.columns if('Bsmt' in x)]
bsmt_features
# Out:
# ['BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'BsmtFullBath',
#  'BsmtHalfBath']

# %%
df[bsmt_features].dtypes
# Out:
# BsmtQual        object
# BsmtCond        object
# BsmtExposure    object
# BsmtFinType1    object
# BsmtFinSF1       int64
# BsmtFinType2    object
# BsmtFinSF2       int64
# BsmtUnfSF        int64
# TotalBsmtSF      int64
# BsmtFullBath     int64
# BsmtHalfBath     int64
# dtype: object

# %%
for feature in bsmt_features:
    
    if(df[feature].dtypes == 'object'):
        
        df[feature]=df[feature].fillna(df[feature].mode()[0])
    else:
        
        df[feature]=df[feature].fillna(df[feature].mean())

# %%
for feature in df.columns:
    
    if(np.round(df[feature].isnull().mean()*100, 2) > 0.0):
        print(feature, "==>", df[feature].dtypes)
# Out:
# Electrical ==> object
# FireplaceQu ==> object
# GarageType ==> object
# GarageYrBlt ==> float64
# GarageFinish ==> object
# GarageQual ==> object
# GarageCond ==> object
# PoolQC ==> object
# Fence ==> object
# MiscFeature ==> object

# %%
df["Electrical"]=df.Electrical.fillna(df.Electrical.mode()[0])
df["FireplaceQu"].value_counts()
# Out:
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64

# %%
df["FireplaceQu"]=df.FireplaceQu.fillna(df.FireplaceQu.mode()[0])

# %%
garage_features = [x for x in df.columns if('Garage' in x)]
garage_features
# Out:
# ['GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageCars',
#  'GarageArea',
#  'GarageQual',
#  'GarageCond']

# %%
df[garage_features].dtypes
# Out:
# GarageType       object
# GarageYrBlt     float64
# GarageFinish     object
# GarageCars        int64
# GarageArea        int64
# GarageQual       object
# GarageCond       object
# dtype: object

# %%
for feature in garage_features:
    
    if(np.round(df[feature].isnull().mean()*100, 2) > 0.0):
        print("{} has {}% of null values i.e {} out of {}".format(
            feature,
            np.round(df[feature].isnull().mean()*100, 2),
            (df[feature].isnull().sum()),
            len(df)
        ))
# Out:
# GarageType has 5.55% of null values i.e 81 out of 1460
# GarageYrBlt has 5.55% of null values i.e 81 out of 1460
# GarageFinish has 5.55% of null values i.e 81 out of 1460
# GarageQual has 5.55% of null values i.e 81 out of 1460
# GarageCond has 5.55% of null values i.e 81 out of 1460

# %%
for feature in garage_features:
    
    if(df[feature].dtypes == 'object'):
        
        df[feature]=df[feature].fillna(df[feature].mode()[0])
    else:
        
        df[feature]=df[feature].fillna(df[feature].mean())

# %%
for feature in df.columns:
    
    if(np.round(df[feature].isnull().mean()*100, 2) > 0.0):
        print("{} has {}% of null values i.e {} out of {}".format(
            feature,
            np.round(df[feature].isnull().mean()*100, 2),
            (df[feature].isnull().sum()),
            len(df)
        ))
# Out:
# PoolQC has 99.52% of null values i.e 1453 out of 1460
# Fence has 80.75% of null values i.e 1179 out of 1460
# MiscFeature has 96.3% of null values i.e 1406 out of 1460

# %%
df.drop(['PoolQC', 'Fence', 'MiscFeature'], axis=1, inplace=True)

# %%
plt.figure(figsize=(20, 8))
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
df.shape
# Out:
# (1460, 76)

# %%
num_features=[x for x in df.columns if df[x].dtypes != 'O']
cat_features=[x for x in df.columns if df[x].dtypes == 'O']

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler
le=LabelEncoder()
sc=StandardScaler()

# %%
for feature in cat_features:
    
    df[feature]=le.fit_transform(df[feature].astype('str'))

# %%
year_feature = [x for x in df.columns if('Yr' in x) or ('Year' in x)]
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for feature in ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt']:
    df[feature]=df["YrSold"]-df[feature]
    
df[year_feature].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt  YrSold
# 0          5             5          5.0    2008
# 1         31            31         31.0    2007
# 2          7             6          7.0    2008
# 3         91            36          8.0    2006
# 4          8             8          8.0    2008

# %%
df.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  LandContour  \
# 0          60         3         65.0     8450       1         3            3
# 1          20         3         80.0     9600       1         3            3
# 2          60         3         68.0    11250       1         0            3
# 3          70         3         60.0     9550       1         0            3
# 4          60         3         84.0    14260       1         0            3
#
#    Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 0          0          4          0             5           2           2
# 1          0          2          0            24           1           2
# 2          0          4          0             5           2           2
# 3          0          0          0             6           2           2
# 4          0          2          0            15           2           2
#
# ...

# %%
train=pd.DataFrame(
    sc.fit_transform(df), columns=df.columns
)
train.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea    Street  LotShape  \
# 0    0.073375 -0.045532    -0.229372 -0.207142  0.064238  0.750731
# 1   -0.872563 -0.045532     0.451936 -0.091886  0.064238  0.750731
# 2    0.073375 -0.045532    -0.093110  0.073480  0.064238 -1.378933
# 3    0.309859 -0.045532    -0.456474 -0.096897  0.064238 -1.378933
# 4    0.073375 -0.045532     0.633618  0.375148  0.064238 -1.378933
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0     0.314667   -0.02618   0.604670  -0.225716     -1.206215   -0.036289
# 1     0.314667   -0.02618  -0.628316  -0.225716      1.954302   -1.188074
# 2     0.314667   -0.02618   0.604670  -0.225716     -1.206215   -0.036289
# 3     0.314667   -0.02618  -1.861302  -0.225716     -1.039872   -0.036289
# 4     0.314667   -0.02618  -0.628316  -0.225716      0.457215   -0.036289
#
#    Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
train.to_csv("Train_dataset.csv")

# %%
train.shape
# Out:
# (1460, 76)
